# %%
import pandas as pd
import matplotlib.pyplot as plt
import cleaning_stephanie as cs
import seaborn as sns
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3853/3675211256.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import cleaning_stephanie as cs
#       4 import seaborn as sns
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'cleaning_stephanie'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
Name_Air_Temp = "Brocket_AGDM_air_temp_precip.txt"
Name_Humidity = "Brocket_AGDM_humidity_wind_radiation.txt"
Name_Soil_Temp = "Brocket_AGDM.csv"
Name_Soil_Moist = "Brocket AGDM.csv"

# %% [markdown]
# #Brocket AGDM
#
# ## Air Temp Precip

# %%
df_air_temp = pd.read_csv(Name_Air_Temp)
df_air_temp.head()
# Out:
#                   time   PR   AT  ATA   TX   TN
# 0  2005-05-01 00:00:00  0.0 -2.5  NaN -1.7 -2.5
# 1  2005-05-01 01:00:00  0.0 -2.9  NaN -2.5 -2.9
# 2  2005-05-01 02:00:00  0.0 -3.3  NaN -2.9 -3.3
# 3  2005-05-01 03:00:00  0.0 -3.6  NaN -3.3 -3.6
# 4  2005-05-01 04:00:00  0.1 -4.0  NaN -3.6 -4.0

# %%
df_air_temp["time"] = pd.to_datetime(df_air_temp["time"])
df_air_temp = df_air_temp.set_index("time")

variables = df_air_temp.columns.values

df_air_temp[variables].plot(subplots=True, figsize=(10, 8), sharex=True)

plt.xlabel("Time")
plt.show()

# %%
df_air_temp = pd.read_csv(Name_Air_Temp)
cs.Air_Temp_Cleaning(df_air_temp)
# Out:
# building tree 1 of 10
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10
# building tree 9 of 10
# building tree 10 of 10
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# MAE PR Model: 0.08132696595267572
# RMSE PR Model: 0.4348668389250015
# PR fitted: 175
# building tree 1 of 10
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10
# building tree 9 of 10
# building tree 10 of 10
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.1s finished
# MAE ATA: 0.14469299830273932
# RMSE ATA: 0.2585013676927789
# ...

# %%
df_air_temp_clean = pd.read_csv("df_Air_Temp_clean.csv")

# %%
df_air_temp_clean["time"] = pd.to_datetime(df_air_temp_clean["time"])
df_air_temp_clean = df_air_temp_clean.set_index("time")

variables = df_air_temp_clean.columns.values

df_air_temp_clean[variables].plot(subplots=True, figsize=(10, 8), sharex=True)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# ## Humidity Wind Radiation

# %%
df_humidity = pd.read_csv(Name_Humidity)
df_humidity.head()
# Out:
#                   time    HU  HUA    WS  WSA   IR
# 0  2005-05-01 00:00:00  79.0  NaN  16.1  NaN  0.0
# 1  2005-05-01 01:00:00  81.1  NaN  12.4  NaN  0.0
# 2  2005-05-01 02:00:00  83.0  NaN  11.4  NaN  0.0
# 3  2005-05-01 03:00:00  85.8  NaN   9.2  NaN  0.0
# 4  2005-05-01 04:00:00  87.0  NaN   9.1  NaN  0.0

# %%
df_humidity["time"] = pd.to_datetime(df_humidity["time"])
df_humidity = df_humidity.set_index("time")

variables = df_humidity.columns.values

df_humidity[variables].plot(subplots=True, figsize=(10, 8), sharex=True)

plt.xlabel("Time")
plt.show()

# %%
from cleaning_stephanie import Air_Rad_Cleaning

# %%
df_humidity = pd.read_csv(Name_Humidity)

Air_Rad_Cleaning(df_humidity)

df_air_rad_clean = pd.read_csv("df_Air_Rad_clean.csv")
# Out:
# IR training samples: 179558
# MAE IR: 149.78026247886837
# RMSE IR: 213.65264705353013
# IR fitted: 169
# HUA training samples: 137131
# MAE HUA: 2.219982377778852
# RMSE HUA: 3.2343063557581146
# HUA fitted: 42596
# WSA training samples: 137114
# MAE WSA: 2.5462883319900897
# RMSE WSA: 3.6153536220325164
# WSA fitted: 42613

# %%
import matplotlib.pyplot as plt

df_air_rad_clean["time"] = pd.to_datetime(df_air_rad_clean["time"])
df_air_rad_clean = df_air_rad_clean.set_index("time")

variables = ["HU", "HUA", "WS", "WSA", "IR"]

df_air_rad_clean[variables].plot(subplots=True, figsize=(10, 8), sharex=True)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Set Colors

# %%
colors = [
    "#5B8DB8",  # Blue
    "#8FC1D4",  # Light blue
    "#D98FA5",  # Light pink
    "#C76B82"   # Pink
]

# %% [markdown]
# ## Soil Temp

# %%
df_Soil_Temp_AGDM=pd.read_csv(Name_Soil_Temp)
df_Soil_Temp_AGDM.head()
# Out:
#                   time  soil_temp_deg_C_at_5_cm_depth  \
# 0  2005-05-01 00:00:00                            5.9
# 1  2005-05-01 01:00:00                            5.6
# 2  2005-05-01 02:00:00                            5.4
# 3  2005-05-01 03:00:00                            5.1
# 4  2005-05-01 04:00:00                            4.9
#
#    soil_temp_deg_C_at_20_cm_depth  soil_temp_deg_C_at_50_cm_depth  \
# 0                             6.5                             6.4
# 1                             6.5                             6.4
# 2                             6.4                             6.4
# 3                             6.4                             6.3
# 4                             6.4                             6.3
#
#    soil_temp_deg_C_at_100_cm_depth
# 0                              6.0
# 1                              6.0
# 2                              6.0
# 3                              6.0
# 4                              6.0

# %%
df_Soil_Temp_AGDM["time"] = pd.to_datetime(df_Soil_Temp_AGDM["time"])
df_Soil_Temp_AGDM = df_Soil_Temp_AGDM.set_index("time")

variables = df_Soil_Temp_AGDM.columns.values

df_Soil_Temp_AGDM[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# ## Repeated Values
# Using percentile of stuck values.

# %% [markdown]
# #Stuck Sensors
#
# ##Percentil Method of Repeated Values
#
# This method discart the .01 percentil of larger sets of repeated values. This is not very worh it wen we fits the predictors models.

# %%
from cleaning_stephanie import repeated_values

# %%
df_clean_stuck=repeated_values(df_Soil_Temp_AGDM,eps=1e-4,percentil=.99)

# %%
df_clean_stuck.iloc[:500][variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time first 100 obs")
plt.show()

# %%
df_clean_stuck[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time first 100 obs")
plt.show()

# %% [markdown]
# #Returns Percentil

# %% [markdown]
# To clean the outlier data, it was decided to analyze temperature changes, which will be referred to as returns, as they will be treated analogously to stock returns. The `conditional_returns` function computes these returns from the dataframe after removing stuck sensor data. If the gap between observations is smaller than the threshold variable `th`, the return is calculated relative to the entry immediately preceding the gap. If the gap is larger than `th`, the return calculation is restarted.
#
# Afterward, the distribution of returns is analyzed, and values above the 99.9th percentile and below the 0.01st percentile are discarded as outliers.

# %%
from cleaning_stephanie import conditional_returns

# %%
returns,returns_per_clean=conditional_returns(df=df_clean_stuck, th=3,low=0.001,up=0.999)
returns.head()
# Out:
#                      soil_temp_deg_C_at_5_cm_depth  \
# time
# 2005-05-01 00:00:00                            NaN
# 2005-05-01 01:00:00                           -0.3
# 2005-05-01 02:00:00                           -0.2
# 2005-05-01 03:00:00                           -0.3
# 2005-05-01 04:00:00                           -0.2
#
#                      soil_temp_deg_C_at_20_cm_depth  \
# time
# 2005-05-01 00:00:00                             NaN
# 2005-05-01 01:00:00                             0.0
# 2005-05-01 02:00:00                            -0.1
# 2005-05-01 03:00:00                             0.0
# 2005-05-01 04:00:00                             0.0
#
#                      soil_temp_deg_C_at_50_cm_depth  \
# time
# 2005-05-01 00:00:00                             NaN
# 2005-05-01 01:00:00                             0.0
# 2005-05-01 02:00:00                             0.0
# 2005-05-01 03:00:00                            -0.1
# 2005-05-01 04:00:00                             0.0
# ...

# %%
low=0.001
up=0.999
lower = returns.quantile(low)
upper = returns.quantile(up)
returns_per_clean =returns.mask((returns < lower) | (returns > upper))

# %%
from cleaning_stephanie import soil_temp_percentil_outliers

# %%
df_Clean_per, returns_per_clean=soil_temp_percentil_outliers(df_clean_stuck,low=0.001,up=0.999,th_returns=3)

# %%
variables = df_Clean_per.columns.values

# plot
df_Clean_per[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")
plt.show()

# %%
df_Clean_per.iloc[:1000][variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)


plt.xlabel("Time first 500 obs")
plt.show()

# %% [markdown]
# # Specific TH Stuck
# In this method we remove any set of repeated values larger than  `sens_stuck `. This method is better for the model fitting part.
#
# ##Neighborhood Outliers
#
# This proposal eliminates an entire neighborhood of size `segment_th` surrounding any value considered an outlier. This is because, when using the returns approach, the first point might be an outlier with respect to the previous normal trend, but subsequent points will be normal with respect to the outlier. However, only the first detected outlier will be eliminated, as subsequent returns would be normal with respect to the removed outlier.
#
# The current method looks for outliers with a positive or negative jump and searches the surroundings for an opposite jump that adjusts to the normal value without counting intermediate NaN values ​​that might be present to remove the section completely.

# %% [markdown]
# ###Returns Removed Using Z Scores
# An outlier is considered to be any return greater than `zscr_sd` standard deviations from the mean.

# %%
from cleaning_stephanie import soil_temp_zscores_neighborhood_outliers

# %%
df_Clean_per,returns_per_clean=soil_temp_zscores_neighborhood_outliers(df=df_Soil_Temp_AGDM,zscr_sd=3,th_returns=2,sens_stuck=20,segment_th = 20)

variables=df_Clean_per.columns.values

df_Clean_per[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")

plt.show()

# %% [markdown]
# ###Returns Removed Using Percentils
# An outlier is considered to be any return that is above the `up` percentile or below the `low` percentile.

# %%
from cleaning_stephanie import soil_temp_percentil_neighborhood_outliers

# %%
df_Clean_per,returns_per_clean=soil_temp_percentil_neighborhood_outliers(df=df_Soil_Temp_AGDM,low=0.00001,up=0.99999,th_returns=200,sens_stuck=50,segment_th = 2)

df_Clean_per[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# #Correlation

# %%
df_all_temp = pd.concat([df_air_temp_clean,df_air_rad_clean, df_Clean_per], axis=1)

# Correlation mtx
corr = df_all_temp.corr()

# heatmap
plt.figure(figsize=(12, 10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0,
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()

# %%
df_all_returns = pd.concat([df_air_temp_clean,df_air_rad_clean, returns_per_clean], axis=1)

# Correlation mtx
corr = df_all_returns.corr()

# heatmap
plt.figure(figsize=(12, 10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0,
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #Temp All Layers
#
# A Lasso model will be used, with the penalization parameter obtained through cross-validation using 5 consecutively divided folds. This approach takes into account the historical nature of the data, where validation should be performed on consecutive sections rather than through random splitting.
#
# As predictor variables, the model will use humidity, radiation, and air temperature values, in addition to the complete temperature data from the previous soil layers. The target variable can be chosen either as the temperature values themselves or as the temperature changes (returns).
#
# The returns approach was selected because it proved to be more stable and provided better performance in short terms. But when it is a large gap is better to predict temperature. In particular, returns produced smoother curves, whereas directly predicting temperatures often resulted in noisier predictions, with connections to subsequent real data points occurring through abrupt jumps.
#
# Models allowed by the function:
#
# *   Lasso="lasso"
# *   LassoCV="lassocv"
# *   Ridge="ridge"
# *   Nerual Network="nn"
#
# Returns:
#
# *   True: Predict returns
# *   False: Predict temperature
#
# ## Same Model For All the layer
# Only returns or temp will be predicted to complete each layer.

# %%
from cleaning_stephanie import soil_temp_model

# %%
returns_per_clean
# Out:
#                      soil_temp_deg_C_at_5_cm_depth  \
# time
# 2005-05-01 00:00:00                            NaN
# 2005-05-01 01:00:00                           -0.3
# 2005-05-01 02:00:00                           -0.2
# 2005-05-01 03:00:00                           -0.3
# 2005-05-01 04:00:00                           -0.2
# ...                                            ...
# 2025-10-31 19:00:00                            NaN
# 2025-10-31 20:00:00                            NaN
# 2025-10-31 21:00:00                            NaN
# 2025-10-31 22:00:00                            NaN
# 2025-10-31 23:00:00                            NaN
#
#                      soil_temp_deg_C_at_20_cm_depth  \
# time
# 2005-05-01 00:00:00                             NaN
# 2005-05-01 01:00:00                             0.0
# 2005-05-01 02:00:00                            -0.1
# 2005-05-01 03:00:00                             0.0
# 2005-05-01 04:00:00                             0.0
# ...

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_temp=df_Clean_per
Y_soil_return=returns_per_clean
Y_soil_temp_fill = Y_soil_temp.copy()
Y_soil_return_fill = Y_soil_return.copy()

# %%
for ly in [5,20,50,100]:
    if ly==5:
        temp_filled, returns_filled, model_5cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==20:
          temp_filled, returns_filled, model_20cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==50:
          temp_filled, returns_filled, model_50cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==100:
          temp_filled, returns_filled, model_100cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    # nombre columna
    col = f"soil_temp_deg_C_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_temp_fill[col] = temp_filled

    # actualizar returns
    if returns_filled is not None:
        Y_soil_return_fill[col] = returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.344e+00, tolerance: 6.434e-01
#   model = cd_fast.enet_coordinate_descent(
# Time-Series Cross-Validation Results:
#    Fold      RMSE       MAE        R2  Directional_Accuracy  \
# 0     1  0.186821  0.146211  0.608889              0.873013
# 1     2  0.189299  0.146117  0.644597              0.891971
# 2     3  0.167082  0.125810  0.563339              0.898535
# 3     4  0.135297  0.108027  0.638506              0.902906
# 4     5  0.193209  0.146831  0.606978              0.887947
#
#    Predicted_Positive_%  Predicted_Negative_%  Actual_Positive_%  \
# 0              0.345189              0.654811           0.388021
# 1              0.352820              0.647180           0.380627
# ...

# %%
temp_depth_clean_same_model=Y_soil_temp_fill

# %% [markdown]
# #### Imput Temperature

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_temp=df_Clean_per
Y_soil_return=returns_per_clean
Y_soil_temp_fill = Y_soil_temp.copy()
Y_soil_return_fill = Y_soil_return.copy()

# %%
for ly in [5,20,50,100]:
    if ly==5:
        temp_filled, returns_filled, model_5cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==20:
          temp_filled, returns_filled, model_20cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==50:
          temp_filled, returns_filled, model_50cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==100:
          temp_filled, returns_filled, model_100cm=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    # nombre columna
    col = f"soil_temp_deg_C_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_temp_fill[col] = temp_filled

    # actualizar returns
    if returns_filled is not None:
        Y_soil_return_fill[col] = returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.68804882990662, tolerance: 53.2641790879086
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.356e+02, tolerance: 1.120e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75.58329847067944, tolerance: 70.79222735596942
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
temp_depth_clean_same_model_Temp=Y_soil_temp_fill

# %% [markdown]
# ## Mixed Model
# Returns and temperature will be predicted for each layer and the gap will be filled using one of the methods depending on whether the gap is greater or less than `gp_th`.

# %%
from cleaning_stephanie import soil_temp_model
from cleaning_stephanie import mix_filling

# %%
gp_th=2000

for ly in [5,20,50,100]:
    if ly==5:

        temp_ret_filled_5cm, returns_filled, model_5cm_ret=soil_temp_model(
                                      X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                      Y_soil_temp_fill, Y_soil_return_fill,
                                      returns=True,model="lassocv",graphs=False,zoom=5,
                                      window_zoom=500,depth=ly
                                      )

        temp_temp_filled_5cm, _, model_5cm_temp=soil_temp_model(
                                      X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                      Y_soil_temp_fill, Y_soil_return_fill,
                                      returns=False,model="lassocv",graphs=False,zoom=5,
                                      window_zoom=500,depth=ly
                                      )

        temp_final = mix_filling(
                                    Y_soil_temp,temp_temp_filled_5cm,
                                    temp_ret_filled_5cm,depth=ly,gap_th = gp_th)

    elif ly==20:
          temp_ret_filled_20cm, returns_filled, model_20cm_ret=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_temp_filled_20cm, _, model_20cm_temp=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_final = mix_filling(
                                      Y_soil_temp,temp_temp_filled_20cm,
                                      temp_ret_filled_20cm,depth=ly,gap_th = gp_th)

    elif ly==50:
          temp_ret_filled_50cm, returns_filled, model_50cm_ret=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_temp_filled_50cm, _, model_50cm_temp=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_final = mix_filling(
                                      Y_soil_temp,temp_temp_filled_50cm,
                                      temp_ret_filled_50cm,depth=ly,gap_th = gp_th)

    elif ly==100:
          temp_ret_filled_100cm, returns_filled, model_100cm_ret=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_temp_filled_100cm, _, model_100cm_temp=soil_temp_model(
                                        X_air_temp,X_air_rad,Y_soil_temp,Y_soil_return,
                                        Y_soil_temp_fill, Y_soil_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          temp_final = mix_filling(
                                      Y_soil_temp,temp_temp_filled_100cm,
                                      temp_ret_filled_100cm,depth=ly,gap_th = gp_th)

    # nombre columna
    col = f"soil_temp_deg_C_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_temp_fill[col] = temp_final

    # actualizar returns
    Y_soil_return_fill[col] = returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.344e+00, tolerance: 6.434e-01
#   model = cd_fast.enet_coordinate_descent(
# Time-Series Cross-Validation Results:
#    Fold      RMSE       MAE        R2  Directional_Accuracy  \
# 0     1  0.186821  0.146211  0.608889              0.873013
# 1     2  0.189299  0.146117  0.644597              0.891971
# 2     3  0.167082  0.125810  0.563339              0.898535
# 3     4  0.135297  0.108027  0.638506              0.902906
# 4     5  0.193209  0.146831  0.606978              0.887947
#
#    Predicted_Positive_%  Predicted_Negative_%  Actual_Positive_%  \
# 0              0.345189              0.654811           0.388021
# 1              0.352820              0.647180           0.380627
# ...

# %%
temp_depth_clean_mixed_model=Y_soil_temp_fill

variables = temp_depth_clean_mixed_model.columns.values

temp_depth_clean_mixed_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %%
temp_depth_clean_mixed_model[variables[0]].plot(subplots=True, figsize=(10, 8), sharex=True)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Performace Comparation
#
# ##Graph Using The Same Model For All The Layer

# %%
variables = temp_depth_clean_same_model.columns.values

temp_depth_clean_same_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %%
variables = temp_depth_clean_same_model_Temp.columns.values

temp_depth_clean_same_model_Temp[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# ## Graph Using Mixed Model

# %%
variables = temp_depth_clean_mixed_model.columns.values

temp_depth_clean_mixed_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Original Data

# %%
variables = df_Soil_Temp_AGDM.columns.values

df_Soil_Temp_AGDM[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Clean After Including Fitting Temperatures

# %%
variables = temp_depth_clean_mixed_model.columns.values

temp_depth_clean_mixed_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #General Conclusions:
#
# Overall, we can observe that the method used to remove outliers and repeated data is effective and allows for a good model fit. Likewise, the models were trained using complete real-world data, and their performance is satisfactory. In short missing sections, the models connect the two real points accurately. In longer missing sections, they are still able to follow the general trend until reaching the next real point, while preserving a certain level of noise, as would be expected in real data, rather than producing a purely linear connection.

# %% [markdown]
# #Interest (outliers) Points

# %% [markdown]
# X_air_temp=df_air_temp_clean
#
# X_air_rad=df_air_rad_clean
#
# Y_soil_temp=df_Clean_per
#
# Y_soil_return=returns_per_clean
#
# ##Temp Filled Mixed Model Interest point Final Tail

# %%
variables = temp_depth_clean_mixed_model.columns.values

temp_depth_clean_mixed_model.iloc[150000:][variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Original Data Final Tail

# %%
variables = df_Soil_Temp_AGDM.columns.values

df_Soil_Temp_AGDM.iloc[150000:][variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# ##Air Humidity Interest Point Final Tail

# %%
variables = ["HU", "HUA", "WS", "WSA", "IR"]

df_air_rad_clean.iloc[150000:][variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# ##Air Temp Interest Point Final Tail

# %%
variables =df_air_temp_clean.columns

df_air_temp_clean.iloc[150000:][variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Interest Point Data Analysis Brocket vs Manning

# %%
Manning_df=pd.read_csv("Manning_AGDM.csv")

# %%
Manning_df["time"] = pd.to_datetime(Manning_df["time"])
Manning_df = Manning_df.set_index("time")

# %% [markdown]
# ## Standard Deviation Temperature

# %%
pd.concat([np.std(Manning_df), np.std(df_Soil_Temp_AGDM)], axis=1).rename(
    columns={0: 'Manning', 1: 'Brocket'})
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:4109: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#                                   Manning   Brocket
# soil_temp_deg_C_at_5_cm_depth    7.563760  7.797150
# soil_temp_deg_C_at_20_cm_depth   6.561497  6.926705
# soil_temp_deg_C_at_50_cm_depth   5.897924  5.770401
# soil_temp_deg_C_at_100_cm_depth  4.551998  4.520265

# %% [markdown]
# ## Mean Temperature

# %%
pd.concat([Manning_df.mean(), df_Soil_Temp_AGDM.mean()], axis=1).rename(
    columns={0: 'Manning', 1: 'Brocket'})
# Out:
#                                   Manning   Brocket
# soil_temp_deg_C_at_5_cm_depth    4.565529  7.426440
# soil_temp_deg_C_at_20_cm_depth   5.201754  7.225547
# soil_temp_deg_C_at_50_cm_depth   6.449308  7.395448
# soil_temp_deg_C_at_100_cm_depth  4.561113  7.450703

# %%
returns_manning,returns_per_clean_manning=conditional_returns(df=Manning_df, th=3,low=0.001,up=0.999)
returns_manning.head()
# Out:
#                      soil_temp_deg_C_at_5_cm_depth  \
# time
# 2005-05-01 00:00:00                            NaN
# 2005-05-01 01:00:00                           -0.1
# 2005-05-01 02:00:00                            0.0
# 2005-05-01 03:00:00                           -0.0
# 2005-05-01 04:00:00                            0.0
#
#                      soil_temp_deg_C_at_20_cm_depth  \
# time
# 2005-05-01 00:00:00                             NaN
# 2005-05-01 01:00:00                             0.1
# 2005-05-01 02:00:00                            -0.1
# 2005-05-01 03:00:00                             0.0
# 2005-05-01 04:00:00                             0.0
#
#                      soil_temp_deg_C_at_50_cm_depth  \
# time
# 2005-05-01 00:00:00                             NaN
# 2005-05-01 01:00:00                             0.0
# 2005-05-01 02:00:00                             0.0
# 2005-05-01 03:00:00                             0.0
# 2005-05-01 04:00:00                             0.0
# ...

# %% [markdown]
# ## Standard Deviation Returns

# %%
pd.concat([np.std(returns_manning), np.std(returns)], axis=1).rename(
    columns={0: 'Returns Manning', 1: 'Returns Brocket'})
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:4109: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#                                  Returns Manning  Returns Brocket
# soil_temp_deg_C_at_5_cm_depth           0.288499         0.355850
# soil_temp_deg_C_at_20_cm_depth          0.224112         0.165078
# soil_temp_deg_C_at_50_cm_depth          0.204364         0.080334
# soil_temp_deg_C_at_100_cm_depth         0.208454         0.099041

# %% [markdown]
# ## Mean Returns

# %%
pd.concat([returns_manning.mean(), returns.mean()], axis=1).rename(
    columns={0: 'Returns Manning ', 1: 'Returns Brocket'})
# Out:
#                                  Returns Manning   Returns Brocket
# soil_temp_deg_C_at_5_cm_depth            0.000052         0.000077
# soil_temp_deg_C_at_20_cm_depth           0.000029         0.000061
# soil_temp_deg_C_at_50_cm_depth           0.000049         0.000134
# soil_temp_deg_C_at_100_cm_depth          0.000051         0.000053

# %%
## Standard Deviation Returns Clean

# %%
pd.concat([np.std(returns_per_clean_manning), np.std(returns_per_clean)], axis=1).rename(
    columns={0: 'Returns Manning Clean', 1: 'Returns Brocket Clean'})
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:4109: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#                                  Returns Manning Clean  Returns Brocket Clean
# soil_temp_deg_C_at_5_cm_depth                 0.243097               0.287345
# soil_temp_deg_C_at_20_cm_depth                0.053374               0.067732
# soil_temp_deg_C_at_50_cm_depth                0.036703               0.034366
# soil_temp_deg_C_at_100_cm_depth               0.033314               0.031475

# %% [markdown]
# ## Mean Returns Clean

# %%
pd.concat([returns_per_clean_manning.mean(), returns_per_clean.mean()], axis=1).rename(
    columns={0: 'Returns Manning Clean', 1: 'Returns Brocket Clean'})
# Out:
#                                  Returns Manning Clean  Returns Brocket Clean
# soil_temp_deg_C_at_5_cm_depth                -0.000543               0.000044
# soil_temp_deg_C_at_20_cm_depth                0.000083               0.000028
# soil_temp_deg_C_at_50_cm_depth               -0.000021               0.000058
# soil_temp_deg_C_at_100_cm_depth              -0.000002               0.000048

# %% [markdown]
# ## Interesant Points Analysis
#
# We can see that the predictor variables don't have as many outliers. The main problem stems from the data in the first layer. Although its measurements are similar to our simpler database, we can easily see that the changes are very noisy and less stable, despite the similarity of the measurements. This makes training the model more difficult, as the predicted variable is very unstable. Finally, because this layer is used to populate the subsequent layers, the error spreads to the later ones.

# %% [markdown]
# # Soil Moisture

# %%
df_Soil_Moisture_AGDM=pd.read_csv(Name_Soil_Moist)
df_Soil_Moisture_AGDM.head()
# Out:
#                   time  soil_moisture_percent_at_5_cm_depth  \
# 0  2005-05-01 00:00:00                                 16.6
# 1  2005-05-01 01:00:00                                 16.6
# 2  2005-05-01 02:00:00                                 16.6
# 3  2005-05-01 03:00:00                                 16.5
# 4  2005-05-01 04:00:00                                 16.5
#
#    soil_moisture_percent_at_20_cm_depth  soil_moisture_percent_at_50_cm_depth  \
# 0                                  29.8                                  34.5
# 1                                  29.8                                  34.5
# 2                                  29.8                                  34.5
# 3                                  29.8                                  34.5
# 4                                  29.8                                  34.5
#
#    soil_moisture_percent_at_100_cm_depth
# 0                                   38.8
# 1                                   38.8
# ...

# %%
df_Soil_Moisture_AGDM["time"] = pd.to_datetime(df_Soil_Moisture_AGDM["time"])
df_Soil_Moisture_AGDM = df_Soil_Moisture_AGDM.set_index("time")

variables = df_Soil_Moisture_AGDM.columns.values

df_Soil_Moisture_AGDM[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %%
df_Clean_per_moist,returns_per_clean_moist=soil_temp_percentil_neighborhood_outliers(df=df_Soil_Moisture_AGDM,low=0.00001,up=0.99999,th_returns=200,sens_stuck=50,segment_th = 5)

# %%
variables = df_Clean_per_moist.columns.values

df_Clean_per_moist[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
from cleaning_stephanie import soil_moist_model

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_ret=returns_per_clean
Y_soil_return_fill=Y_soil_return_fill
Y_soil_moist=df_Clean_per_moist
Y_soil_moist_return=returns_per_clean_moist
Y_soil_moist_fill=df_Clean_per_moist.copy()
Y_soil_moist_return_fill=returns_per_clean_moist.copy()

# %%
soil_moist_model(X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                         Y_soil_moist, Y_soil_moist_return,
                         Y_soil_moist_fill, Y_soil_moist_return_fill,
                         returns=True,model="lassocv",graphs=True,zoom=5,
                         window_zoom=500,depth=5)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03505005727851085, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03565002123332306, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03623949528127923, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %% [markdown]
# # All Layers

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_ret=returns_per_clean
Y_soil_return_fill=Y_soil_return_fill
Y_soil_moist=df_Clean_per_moist
Y_soil_moist_return=returns_per_clean_moist
Y_soil_moist_fill=df_Clean_per_moist.copy()
Y_soil_moist_return_fill=returns_per_clean_moist.copy()

# %%
for ly in [5,20,50,100]:
    if ly==5:
        moist_filled, moist_returns_filled, moist_model_5cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==20:
          moist_filled, moist_returns_filled, moist_model_20cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==50:
          moist_filled, moist_returns_filled, moist_model_50cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==100:
          moist_filled, moist_returns_filled, moist_model_100cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=True,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    # nombre columna
    col = f"soil_moisture_percent_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_moist_fill[col] = moist_filled

    # actualizar returns
    if moist_returns_filled is not None:
        Y_soil_moist_return_fill[col] = moist_returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03505005727851085, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03565002123332306, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03623949528127923, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %% [markdown]
# # Moisture Original

# %%
variables = df_Soil_Moisture_AGDM.columns.values

df_Soil_Moisture_AGDM[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# # Moisture Clean No Filled

# %%
variables = df_Clean_per_moist.columns.values

df_Clean_per_moist[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Moisture Filled Unique

# %%
moist_depth_clean_unique_model=Y_soil_moist_fill

variables = moist_depth_clean_unique_model.columns.values

moist_depth_clean_unique_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# # Mixed Model
#
# Returns and moisture will be predicted for each layer and the gap will be filled using one of the methods depending on whether the gap is greater or less than `gp_th`.

# %%
from cleaning_stephanie import mix_filling_moisture

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_ret=returns_per_clean
Y_soil_return_fill=Y_soil_return_fill
Y_soil_moist=df_Clean_per_moist
Y_soil_moist_return=returns_per_clean_moist
Y_soil_moist_fill=df_Clean_per_moist.copy()
Y_soil_moist_return_fill=returns_per_clean_moist.copy()

# %%
gp_th=20000

for ly in [5,20,50,100]:
    if ly==5:

        mois_ret_filled_5cm, returns_filled, model_5cm_ret=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                      returns=True,model="lassocv",graphs=False,zoom=5,
                                      window_zoom=500,depth=ly
                                      )

        mois_mois_filled_5cm, _, model_5cm_temp=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                      returns=False,model="lassocv",graphs=False,zoom=5,
                                      window_zoom=500,depth=ly
                                      )

        mois_final = mix_filling_moisture(
                                    Y_soil_moist,mois_mois_filled_5cm,
                                    mois_ret_filled_5cm,depth=ly,gap_th = gp_th)

    elif ly==20:
          mois_ret_filled_20cm, returns_filled, model_20cm_ret=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_mois_filled_20cm, _, model_20cm_temp=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_final = mix_filling_moisture(
                                      Y_soil_moist,mois_mois_filled_20cm,
                                      mois_ret_filled_20cm,depth=ly,gap_th = gp_th)

    elif ly==50:
          mois_ret_filled_50cm, returns_filled, model_50cm_ret=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_mois_filled_50cm, _, model_50cm_temp=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_final = mix_filling_moisture(
                                      Y_soil_moist,mois_mois_filled_50cm,
                                      mois_ret_filled_50cm,depth=ly,gap_th = gp_th)

    elif ly==100:
          mois_ret_filled_100cm, returns_filled, model_100cm_ret=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=True,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_mois_filled_100cm, _, model_100cm_temp=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )

          mois_final = mix_filling_moisture(
                                      Y_soil_moist,mois_mois_filled_100cm,
                                      mois_ret_filled_100cm,depth=ly,gap_th = gp_th)

    # nombre columna
    col = f"soil_moisture_percent_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_moist_fill[col] = mois_final

    # actualizar returns
    Y_soil_moist_return_fill[col] = returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03505005727851085, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03565002123332306, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03623949528127923, tolerance: 0.034422897628156084
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %% [markdown]
# # Moist Filled Mixed Model

# %%
mois_depth_clean_mixed_model=Y_soil_moist_fill

variables = mois_depth_clean_mixed_model.columns.values

mois_depth_clean_mixed_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# # Moisture Original

# %%
variables = df_Soil_Moisture_AGDM.columns.values

df_Soil_Moisture_AGDM[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# # Moisture Clean No Filled

# %%
variables = df_Clean_per_moist.columns.values

df_Clean_per_moist[variables].plot(
    subplots=True,
    figsize=(10, 8),
    sharex=True,
    color=colors
)

plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Moisture Filled Unique

# %%
variables = moist_depth_clean_unique_model.columns.values

moist_depth_clean_unique_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# # Moist Filled Mixed Model

# %%
mois_depth_clean_mixed_model=Y_soil_moist_fill

variables = mois_depth_clean_mixed_model.columns.values

mois_depth_clean_mixed_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %% [markdown]
# #Mois Filed Using Moist Direct

# %%
X_air_temp=df_air_temp_clean
X_air_rad=df_air_rad_clean
Y_soil_ret=returns_per_clean
Y_soil_return_fill=Y_soil_return_fill
Y_soil_moist=df_Clean_per_moist
Y_soil_moist_return=returns_per_clean_moist
Y_soil_moist_fill=df_Clean_per_moist.copy()
Y_soil_moist_return_fill=returns_per_clean_moist.copy()

# %%
for ly in [5,20,50,100]:
    if ly==5:
        moist_filled, moist_returns_filled, moist_model_5cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==20:
          moist_filled, moist_returns_filled, moist_model_20cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==50:
          moist_filled, moist_returns_filled, moist_model_50cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    elif ly==100:
          moist_filled, moist_returns_filled, moist_model_100cm=soil_moist_model(
                                        X_air_temp,X_air_rad, Y_soil_ret, Y_soil_return_fill,
                                        Y_soil_moist, Y_soil_moist_return,
                                        Y_soil_moist_fill, Y_soil_moist_return_fill,
                                        returns=False,model="lassocv",graphs=False,zoom=5,
                                        window_zoom=500,depth=ly
                                        )
    # nombre columna
    col = f"soil_moisture_percent_at_{ly}_cm_depth"

    # actualizar temperaturas
    Y_soil_moist_fill[col] = moist_filled

    # actualizar returns
    if moist_returns_filled is not None:
        Y_soil_moist_return_fill[col] = moist_returns_filled
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311.4976235908107, tolerance: 37.36034558282498
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 765.4774688803591, tolerance: 37.36034558282498
#   model = cd_fast.enet_coordinate_descent_gram(
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1059.4205686236965, tolerance: 37.36034558282498
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
moist_depth_clean_unique_model=Y_soil_moist_fill

variables = moist_depth_clean_unique_model.columns.values

moist_depth_clean_unique_model[variables].plot(subplots=True, figsize=(10, 8), sharex=True,
    color=colors)

plt.xlabel("Time")
plt.show()

# %%
df_Clean_per.isna().sum()
# Out:
# soil_temp_deg_C_at_5_cm_depth       69715
# soil_temp_deg_C_at_20_cm_depth      49902
# soil_temp_deg_C_at_50_cm_depth      84259
# soil_temp_deg_C_at_100_cm_depth    111438
# dtype: int64

# %%
col = 'soil_temp_deg_C_at_100_cm_depth'

# puntos que fueron eliminados en el limpio
bad_mask = df_Clean_per[col].isna()

plt.figure(figsize=(15,4))

# serie original completa
plt.plot(df_Soil_Temp_AGDM.index,
         df_Soil_Temp_AGDM[col],
         alpha=0.3)

# puntos eliminados resaltados
plt.scatter(df_Soil_Temp_AGDM.index[bad_mask],
            df_Soil_Temp_AGDM.loc[bad_mask, col],
            s=5)

plt.title(f'Puntos eliminados - {col}')
plt.show()

# %%
df_Soil_Temp_AGDM=pd.read_csv(Name_Soil_Mois)
df_Soil_Temp_AGDM.head()
# Out:
#                   time  soil_temp_deg_C_at_5_cm_depth  \
# 0  2005-05-01 00:00:00                            0.1
# 1  2005-05-01 01:00:00                            0.0
# 2  2005-05-01 02:00:00                            0.0
# 3  2005-05-01 03:00:00                           -0.0
# 4  2005-05-01 04:00:00                           -0.0
#
#    soil_temp_deg_C_at_20_cm_depth  soil_temp_deg_C_at_50_cm_depth  \
# 0                             0.7                             1.2
# 1                             0.8                             1.2
# 2                             0.7                             1.2
# 3                             0.7                             1.2
# 4                             0.7                             1.2
#
#    soil_temp_deg_C_at_100_cm_depth
# 0                             -0.4
# 1                             -0.4
# 2                             -0.4
# 3                             -0.4
# 4                             -0.3

# %% [markdown]
# ###Returns Removed Using Percentils
# An outlier is considered to be any return that is above the `up` percentile or below the `low` percentile.
